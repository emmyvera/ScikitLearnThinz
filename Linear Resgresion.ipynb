# %%
from sklearn.datasets import load_breast_cancer
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt

cancer = load_breast_cancer()

X_train, X_test, y_train, y_test = train_test_split(cancer.data, cancer.target, stratify=cancer.target, random_state=42)

log_reg = LogisticRegression()
log_reg.fit(X_train, y_train)
# Out:
# /home/emmyvera/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
print("Accuracy on the training subset: {:.3f}".format(log_reg.score(X_train,y_train)))
print("Accuracy on the test subset: {:.3f}".format(log_reg.score(X_test,y_test)))
# Out:
# Accuracy on the training subset: 0.953
# Accuracy on the test subset: 0.958

# %%
logR100 = LogisticRegression(C=100)
logR100.fit(X_train, y_train)
print("Accuracy on the training subset: {:.3f}".format(logR100.score(X_train,y_train)))
print("Accuracy on the test subset: {:.3f}".format(logR100.score(X_test,y_test)))
# Out:
# Accuracy on the training subset: 0.967
# Accuracy on the test subset: 0.965
# /home/emmyvera/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
logR001 = LogisticRegression(C=0.01)
logR001.fit(X_train, y_train)
print("Accuracy on the training subset: {:.3f}".format(logR001.score(X_train,y_train)))
print("Accuracy on the test subset: {:.3f}".format(logR001.score(X_test,y_test)))
# Out:
# Accuracy on the training subset: 0.934
# Accuracy on the test subset: 0.930
# /home/emmyvera/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
plt.plot(log_reg.coef_.T, "o", label="C=1")
plt.plot(logR100.coef_.T, "^", label="C=100")
plt.plot(logR001.coef_.T, "v", label="C=0.01")
plt.xticks(range(cancer.data.shape[1]), cancer.feature_names, rotation=90)
plt.hlines(0,0,cancer.data.shape[1])
plt.ylim(-5,5)
plt.xlabel("Coefficient Index")
plt.ylabel("Coefficient Magnitude")
plt.legend()
